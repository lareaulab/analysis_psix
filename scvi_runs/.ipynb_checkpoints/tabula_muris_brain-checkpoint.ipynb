# %%
import scanpy as sc
import scvi
import numpy as np
import pandas as pd
import anndata
import os

# %%
counts = pd.read_csv('data_tm/star_counts.tab', index_col=0)
rd = pd.read_csv('data_tm/rd.tab', sep='\t', index_col=0)
# meta = pd.read_csv('data_ml/SraRunTable.txt', index_col=0)
# star_meta = pd.read_csv('data_tm/star_meta.tab', sep='\t', index_col=0)

# discard = ['EGFP'] + [x for x in counts.index if x[:5]=='ERCC-']
# good_genes = [x for x in counts.index if x not in discard]
# Out:
# INFO     No batch_key inputted, assuming all cells are same batch
# INFO     No label_key inputted, assuming all cells have same label
# INFO     Using data from adata.layers["counts"]
# INFO     Computing library size prior per batch
# INFO     Successfully registered anndata object containing 6021 cells, 32441 genes, 1
#          batches, 1 labels, and 0 proteins. Also registered 0 extra categorical covariates
#          and 0 extra continuous covariates.
# INFO     Please do not further modify adata until model is trained.
# /home/eecs/cfbuenabadn/anaconda3/envs/scvi-env/lib/python3.7/site-packages/scanpy/preprocessing/_highly_variable_genes.py:144: FutureWarning: Slicing a positional slice with .loc is not supported, and will raise TypeError in a future version.  Use .loc with labels or .iloc with positions instead.
#   df.loc[: int(n_top_genes), 'highly_variable'] = True
# INFO     No batch_key inputted, assuming all cells are same batch
# INFO     No label_key inputted, assuming all cells have same label
# INFO     Using data from adata.layers["counts"]
# INFO     Computing library size prior per batch
# INFO     Successfully registered anndata object containing 6021 cells, 2000 genes, 1 batches,
#          1 labels, and 0 proteins. Also registered 0 extra categorical covariates and 0 extra
#          continuous covariates.
# INFO     Please do not further modify adata until model is trained.
# INFO     KL warmup for 400 epochs
# Output()
# INFO     Training time:  1755 s. / 400 epochs
# /home/eecs/cfbuenabadn/anaconda3/envs/scvi-env/lib/python3.7/site-packages/numba/np/ufunc/parallel.py:363: NumbaWarning: The TBB threading layer requires TBB version 2019.5 or later i.e., TBB_INTERFACE_VERSION >= 11005. Found TBB_INTERFACE_VERSION = 9002. The TBB threading layer is disabled.
#   warnings.warn(problem)

# %%
sc.pl.umap(
    adata,
#     gene_symbols='Snap25',
    color="Tbx4",
    frameon=False
)

# %%
scvi_rd = pd.DataFrame(adata.obsm['X_scVI'])
scvi_rd.index = adata.obs.index
scvi_rd.columns = ['scvi_' + str(x) for x in range(1, 11)]

scvi_rd.to_csv('tm_scvi_rd.tab', sep='\t', index=True, header=True)

# %%
accession_map = pd.read_csv('data_tm/GSE109774_list_of_SRR_accessions_and_raw_filenames.txt', sep='\t', index_col=1,
                           names=['GSM', 'fq1', 'fq2'])
annotations = pd.read_csv('data_tm/annotations_facs.csv', index_col=2)
# Out:
# /home/eecs/cfbuenabadn/anaconda3/envs/scvi-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (0,1) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
accession_map = accession_map.loc[rd.index]
annotations_id = ['.'.join(accession_map.loc[cell].fq1[:-15].split('-')) for cell in rd.index]
accession_map['annotations_id'] = annotations_id
annotations_cells = annotations.index & pd.Index(annotations_id)

# %%
cell_type = []
subtissue = []
sex = []
for idx, row in accession_map.iterrows():
    try:
        cell_type.append(annotations.loc[row.annotations_id, 'cell_ontology_class'])
        subtissue.append(annotations.loc[row.annotations_id, 'subtissue'])
        sex.append(annotations.loc[row.annotations_id, 'mouse.sex'])
    except:
        cell_type.append('unknown')
        subtissue.append('unknown')
        sex.append('unknown')

# %%
counts = counts[rd.index].T

adata = anndata.AnnData(counts)

sc.pp.filter_genes(adata, min_counts=3)
sc.pp.filter_cells(adata, min_counts=3)

adata.layers["counts"] = adata.X.copy()


sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)
adata.raw = adata


scvi.data.setup_anndata(adata, layer="counts")

sc.set_figure_params(figsize=(4, 4))


sc.pp.highly_variable_genes(
    adata,
    n_top_genes=2000,
    subset=True,
    layer="counts",
    flavor="seurat_v3"
)


scvi.data.setup_anndata(adata, layer="counts")

model = scvi.model.SCVI(adata)


model.train()


model.save("my_model_tm/")


latent = model.get_latent_representation()
adata.obsm["X_scVI"] = latent

adata.layers["scvi_normalized"] = model.get_normalized_expression(
    library_size=10e4
)

sc.pp.neighbors(adata, use_rep="X_scVI")
sc.tl.umap(adata, min_dist=0.2)

sc.tl.pca(adata)


adata.obs['cell_type'] = cell_type
adata.obs['subtissue'] = subtissue
adata.obs['sex'] = sex
# Out:
#                         Neurog3>0_raw Neurog3>0_scaled cell_ontology_class  \
# A1.B003290.3_38_F.1.1             NaN              NaN           astrocyte
# A1.B003290.3_38_F.1.1             NaN              NaN           astrocyte
# A1.B003728.3_56_F.1.1             NaN              NaN           astrocyte
# A1.B003728.3_56_F.1.1             NaN              NaN           astrocyte
# A1.MAA000560.3_10_M.1.1           NaN              NaN     oligodendrocyte
# ...                               ...              ...                 ...
# P9.MAA000930.3_8_M.1.1            NaN              NaN           astrocyte
# P9.MAA000932.3_11_M.1.1           NaN              NaN    endothelial cell
# P9.MAA000935.3_8_M.1.1            NaN              NaN     oligodendrocyte
# P9.MAA001894.3_39_F.1.1           NaN              NaN           astrocyte
# P9.MAA001894.3_39_F.1.1           NaN              NaN           astrocyte
#
#                         cell_ontology_id  cluster.ids free_annotation  \
# A1.B003290.3_38_F.1.1         CL:0000127            2             NaN
# A1.B003290.3_38_F.1.1         CL:0000127            2             NaN
# A1.B003728.3_56_F.1.1         CL:0000127            2             NaN
# A1.B003728.3_56_F.1.1         CL:0000127            2             NaN
# A1.MAA000560.3_10_M.1.1       CL:0000128            0             NaN
# ...                                  ...          ...             ...
# P9.MAA000930.3_8_M.1.1        CL:0000127            2             NaN
# P9.MAA000932.3_11_M.1.1       CL:0000115            5             NaN
# P9.MAA000935.3_8_M.1.1        CL:0000128            0             NaN
# P9.MAA001894.3_39_F.1.1       CL:0000127            2             NaN
# P9.MAA001894.3_39_F.1.1       CL:0000127            2             NaN
#
#                         mouse.id mouse.sex plate.barcode subsetA  ...  \
# A1.B003290.3_38_F.1.1     3_38_F         F       B003290    True  ...
# A1.B003290.3_38_F.1.1     3_38_F         F       B003290    True  ...
# A1.B003728.3_56_F.1.1     3_56_F         F       B003728    True  ...
# A1.B003728.3_56_F.1.1     3_56_F         F       B003728    True  ...
# A1.MAA000560.3_10_M.1.1   3_10_M         M     MAA000560   False  ...
# ...                          ...       ...           ...     ...  ...
# P9.MAA000930.3_8_M.1.1     3_8_M         M     MAA000930    True  ...
# P9.MAA000932.3_11_M.1.1   3_11_M         M     MAA000932   False  ...
# P9.MAA000935.3_8_M.1.1     3_8_M         M     MAA000935   False  ...
# P9.MAA001894.3_39_F.1.1   3_39_F         F     MAA001894    True  ...
# P9.MAA001894.3_39_F.1.1   3_39_F         F     MAA001894    True  ...
#
#                          subsetC subsetC_cluster.ids  subsetD  \
# A1.B003290.3_38_F.1.1        NaN                 NaN      NaN
# A1.B003290.3_38_F.1.1        NaN                 NaN      NaN
# A1.B003728.3_56_F.1.1        NaN                 NaN      NaN
# A1.B003728.3_56_F.1.1        NaN                 NaN      NaN
# A1.MAA000560.3_10_M.1.1      NaN                 NaN      NaN
# ...                          ...                 ...      ...
# P9.MAA000930.3_8_M.1.1       NaN                 NaN      NaN
# P9.MAA000932.3_11_M.1.1      NaN                 NaN      NaN
# P9.MAA000935.3_8_M.1.1       NaN                 NaN      NaN
# P9.MAA001894.3_39_F.1.1      NaN                 NaN      NaN
# P9.MAA001894.3_39_F.1.1      NaN                 NaN      NaN
#
#                         subsetD_cluster.ids  subsetE subsetE_cluster.ids  \
# A1.B003290.3_38_F.1.1                   NaN      NaN                 NaN
# A1.B003290.3_38_F.1.1                   NaN      NaN                 NaN
# A1.B003728.3_56_F.1.1                   NaN      NaN                 NaN
# A1.B003728.3_56_F.1.1                   NaN      NaN                 NaN
# A1.MAA000560.3_10_M.1.1                 NaN      NaN                 NaN
# ...                                     ...      ...                 ...
# P9.MAA000930.3_8_M.1.1                  NaN      NaN                 NaN
# P9.MAA000932.3_11_M.1.1                 NaN      NaN                 NaN
# P9.MAA000935.3_8_M.1.1                  NaN      NaN                 NaN
# P9.MAA001894.3_39_F.1.1                 NaN      NaN                 NaN
# P9.MAA001894.3_39_F.1.1                 NaN      NaN                 NaN
#
#                            subtissue             tissue  tissue_tSNE_1  \
# A1.B003290.3_38_F.1.1       Striatum  Brain_Non-Myeloid      18.896128
# A1.B003290.3_38_F.1.1       Striatum  Brain_Non-Myeloid      18.896128
# A1.B003728.3_56_F.1.1       Striatum  Brain_Non-Myeloid      11.135658
# A1.B003728.3_56_F.1.1       Striatum  Brain_Non-Myeloid      11.135658
# A1.MAA000560.3_10_M.1.1       Cortex  Brain_Non-Myeloid      -9.626525
# ...                              ...                ...            ...
# P9.MAA000930.3_8_M.1.1        Cortex  Brain_Non-Myeloid      25.653646
# P9.MAA000932.3_11_M.1.1  Hippocampus  Brain_Non-Myeloid      -6.759615
# P9.MAA000935.3_8_M.1.1   Hippocampus  Brain_Non-Myeloid     -19.376459
# P9.MAA001894.3_39_F.1.1       Cortex  Brain_Non-Myeloid      10.990470
# P9.MAA001894.3_39_F.1.1       Cortex  Brain_Non-Myeloid      10.990470
#
#                         tissue_tSNE_2
# A1.B003290.3_38_F.1.1        3.803646
# A1.B003290.3_38_F.1.1        3.803646
# A1.B003728.3_56_F.1.1        8.963120
# A1.B003728.3_56_F.1.1        8.963120
# A1.MAA000560.3_10_M.1.1    -11.191438
# ...                               ...
# P9.MAA000930.3_8_M.1.1      16.267798
# P9.MAA000932.3_11_M.1.1     31.786409
# P9.MAA000935.3_8_M.1.1     -11.004535
# P9.MAA001894.3_39_F.1.1      9.440423
# P9.MAA001894.3_39_F.1.1      9.440423
#
# [5892 rows x 23 columns]

# %%
sr_id = accession_map.index
accession_map = accession_map.set_index('annotations_id')
accession_map['SR_id'] = sr_id

# %%
accession_map.loc[annotations_cells]
# Out:
#                                 GSM                                     fq1  \
# annotations_id
# A1.B003290.3_38_F.1.1    GSM2967047    A1-B003290-3_38_F-1-1_C1_R1.fastq.gz
# A1.B003290.3_38_F.1.1    GSM2967047    A1-B003290-3_38_F-1-1_C2_R1.fastq.gz
# A1.B003290.3_38_F.1.1    GSM2967047    A1-B003290-3_38_F-1-1_C1_R1.fastq.gz
# A1.B003290.3_38_F.1.1    GSM2967047    A1-B003290-3_38_F-1-1_C2_R1.fastq.gz
# A1.B003728.3_56_F.1.1    GSM2967047    A1-B003728-3_56_F-1-1_C1_R1.fastq.gz
# ...                             ...                                     ...
# P9.MAA000935.3_8_M.1.1   GSM2967047   P9-MAA000935-3_8_M-1-1_C1_R1.fastq.gz
# P9.MAA001894.3_39_F.1.1  GSM2967047  P9-MAA001894-3_39_F-1-1_C1_R1.fastq.gz
# P9.MAA001894.3_39_F.1.1  GSM2967047  P9-MAA001894-3_39_F-1-1_C2_R1.fastq.gz
# P9.MAA001894.3_39_F.1.1  GSM2967047  P9-MAA001894-3_39_F-1-1_C1_R1.fastq.gz
# P9.MAA001894.3_39_F.1.1  GSM2967047  P9-MAA001894-3_39_F-1-1_C2_R1.fastq.gz
#
#                                                             fq2       SR_id
# annotations_id
# A1.B003290.3_38_F.1.1      A1-B003290-3_38_F-1-1_C1_R2.fastq.gz  SRR6532522
# A1.B003290.3_38_F.1.1      A1-B003290-3_38_F-1-1_C2_R2.fastq.gz  SRR6532523
# A1.B003290.3_38_F.1.1      A1-B003290-3_38_F-1-1_C1_R2.fastq.gz  SRR6532522
# A1.B003290.3_38_F.1.1      A1-B003290-3_38_F-1-1_C2_R2.fastq.gz  SRR6532523
# A1.B003728.3_56_F.1.1      A1-B003728-3_56_F-1-1_C1_R2.fastq.gz  SRR6532798
# ...                                                         ...         ...
# P9.MAA000935.3_8_M.1.1    P9-MAA000935-3_8_M-1-1_C1_R2.fastq.gz  SRR6539825
# P9.MAA001894.3_39_F.1.1  P9-MAA001894-3_39_F-1-1_C1_R2.fastq.gz  SRR6531939
# P9.MAA001894.3_39_F.1.1  P9-MAA001894-3_39_F-1-1_C2_R2.fastq.gz  SRR6531941
# P9.MAA001894.3_39_F.1.1  P9-MAA001894-3_39_F-1-1_C1_R2.fastq.gz  SRR6531939
# P9.MAA001894.3_39_F.1.1  P9-MAA001894-3_39_F-1-1_C2_R2.fastq.gz  SRR6531941
#
# [11156 rows x 4 columns]
