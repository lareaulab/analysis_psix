# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import os
import sys
from tqdm import tqdm
sys.path.insert(0, '/mnt/lareaulab/cfbuenabadn/psix_project/psix/psix/')
import psix

cm = 1/2.54

plt.rcParams["axes.edgecolor"] = "black"
plt.rcParams["axes.linewidth"] = 1
plt.rcParams["axes.facecolor"] = 'white'

import matplotlib as mpl
import numpy as np

mpl.rcParams["mathtext.fontset"] = "stix"
mpl.rcParams['pdf.fonttype'] = 42

# %%
latent = pd.read_csv('data/preprocess/tables/pc3_rd.tab.gz', sep='\t', index_col=0)

# %%
psix_object = psix.Psix()
psix_object.process_rnaseq_solo(
        '/mnt/lareaulab/cfbuenabadn/RNASeq/Mouse/Tiklova/STARsolo/star_output/Solo.out/SJ/raw',
        '~/Genomes/pipeline_files/mm10_introns.tab',
        cell_list = latent.index,
        tpm_file = 'data/preprocess/tables/rsem_gene_tpm_filtered.tab.gz',
        )
# Out:
# Reading solo splice junctions
# getting barcodes
# getting matrix
# Obtaining PSI tables...
# getting psi table
# Reading TPM and transforming to mRNA counts...
# 100%|██████████| 1067/1067 [00:50<00:00, 21.05it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/pandas/core/internals/blocks.py in replace(self, to_replace, value, inplace, filter, regex, convert)
#     773         try:
# --> 774             blocks = self.putmask(mask, value, inplace=inplace)
#     775             # Note: it is _not_ the case that self._can_hold_element(value)
#
# ~/.local/lib/python3.7/site-packages/pandas/core/internals/blocks.py in putmask(self, mask, new, align, inplace, axis, transpose)
#    1675
# -> 1676         new_values[mask] = new
#    1677         return [self.make_block(values=new_values)]
#
# ~/.local/lib/python3.7/site-packages/pandas/core/arrays/sparse/array.py in __setitem__(self, key, value)
#     460         msg = "SparseArray does not support item assignment via setitem"
# --> 461         raise TypeError(msg)
#     462
#
# TypeError: SparseArray does not support item assignment via setitem
#
# During handling of the above exception, another exception occurred:
#
# AssertionError                            Traceback (most recent call last)
# <ipython-input-3-8f082cc99dc7> in <module>
#       4         '~/Genomes/pipeline_files/mm10_introns.tab',
#       5         cell_list = latent.index,
# ----> 6         tpm_file = 'data/preprocess/tables/rsem_gene_tpm_filtered.tab.gz',
#       7         )
#
# ~/psix_project/psix/psix/psix.py in process_rnaseq_solo(self, solo_dir, intron_tab, cell_list, tpm_file, minJR, minCell, min_psi, min_observed, tenX)
#     219                 min_psi = min_psi,
#     220                 min_observed = min_observed,
# --> 221                 tenX = tenX
#     222             )
#     223
#
# ~/psix_project/psix/psix/rnaseq_tools.py in process_rnaseq_solo(self, solo_dir, intron_tab, cell_list, tpm_file, minJR, minCell, min_psi, min_observed, tenX)
#     262         psi = psi[cells]
#     263
# --> 264         mrna_per_event = get_mrna_per_event(mrna, psi, reads, intron_mtx_CI) #constitutive_sj_file)
#     265
#     266     if len(self.adata.obs) > 0:
#
# ~/psix_project/psix/psix/rnaseq_tools.py in get_mrna_per_event(mrna, psi, reads, constitutive_sj)
#      20     mrna_per_junction.index = obs_junctions
#      21
# ---> 22     reads_per_junction = (constitutive_sj.loc[obs_junctions] / mrna_per_junction).replace([np.inf, -np.inf], np.nan)
#      23     SJ_mean = reads_per_junction.mean()
#      24
#
# ~/.local/lib/python3.7/site-packages/pandas/core/frame.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    4170             limit=limit,
#    4171             regex=regex,
# -> 4172             method=method,
#    4173         )
#    4174
#
# ~/.local/lib/python3.7/site-packages/pandas/core/generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    6702                 else:  # [NA, ''] -> 0
#    6703                     new_data = self._data.replace(
# -> 6704                         to_replace=to_replace, value=value, inplace=inplace, regex=regex
#    6705                     )
#    6706             elif to_replace is None:
#
# ~/.local/lib/python3.7/site-packages/pandas/core/internals/managers.py in replace(self, value, **kwargs)
#     587     def replace(self, value, **kwargs):
#     588         assert np.ndim(value) == 0, value
# --> 589         return self.apply("replace", value=value, **kwargs)
#     590
#     591     def replace_list(self, src_list, dest_list, inplace=False, regex=False):
#
# ~/.local/lib/python3.7/site-packages/pandas/core/internals/managers.py in apply(self, f, filter, **kwargs)
#     440                 applied = b.apply(f, **kwargs)
#     441             else:
# --> 442                 applied = getattr(b, f)(**kwargs)
#     443             result_blocks = _extend_blocks(applied, result_blocks)
#     444
#
# ~/.local/lib/python3.7/site-packages/pandas/core/internals/blocks.py in replace(self, to_replace, value, inplace, filter, regex, convert)
#     785                 raise
#     786
# --> 787             assert not self._can_hold_element(value), value
#     788
#     789             # try again with a compatible block
#
# AssertionError: nan

# %%
psix_object.compute_psix_scores(latent='data/preprocess/tables/pc3_rd.tab.gz', n_jobs=25, 
                                n_random_exons=2000, n_neighbors=100)

# %%
from rnaseq_tools import *

# %%
intron_mtx_CI, intron_mtx_exons = process_solo('/mnt/lareaulab/cfbuenabadn/RNASeq/Mouse/Tiklova/STARsolo/star_output/Solo.out/SJ/raw',
        '~/Genomes/pipeline_files/mm10_introns.tab',
        cell_list = latent.index)
# Out:
# Reading solo splice junctions
# getting barcodes
# getting matrix

# %%
psi, reads = get_psi_table_solo(intron_mtx_exons, 1, 1, tenX=False)

alt_exons = psi.index[np.abs(0.5 - psi.mean(axis=1)) <= (0.5-0.05)]
obs_exons = psi.index[psi.isna().mean(axis=1) <= 1-0.25]
selected_exons = alt_exons & obs_exons

psi = psi.loc[selected_exons]
reads = reads.loc[selected_exons]
# Out:
# getting psi table

# %%
mrna = tpm_to_mrna2('data/preprocess/tables/rsem_gene_tpm_filtered.tab.gz')
##### New thing
cells = psi.columns & mrna.columns
mrna = mrna[cells]
psi = psi[cells]

mrna_per_event = get_mrna_per_event(mrna, psi, reads, intron_mtx_CI) #constitutive_sj_file)
# Out:
# 100%|██████████| 1067/1067 [00:50<00:00, 21.20it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/pandas/core/internals/blocks.py in replace(self, to_replace, value, inplace, filter, regex, convert)
#     773         try:
# --> 774             blocks = self.putmask(mask, value, inplace=inplace)
#     775             # Note: it is _not_ the case that self._can_hold_element(value)
#
# ~/.local/lib/python3.7/site-packages/pandas/core/internals/blocks.py in putmask(self, mask, new, align, inplace, axis, transpose)
#    1675
# -> 1676         new_values[mask] = new
#    1677         return [self.make_block(values=new_values)]
#
# ~/.local/lib/python3.7/site-packages/pandas/core/arrays/sparse/array.py in __setitem__(self, key, value)
#     460         msg = "SparseArray does not support item assignment via setitem"
# --> 461         raise TypeError(msg)
#     462
#
# TypeError: SparseArray does not support item assignment via setitem
#
# During handling of the above exception, another exception occurred:
#
# AssertionError                            Traceback (most recent call last)
# <ipython-input-16-4466755ddbee> in <module>
#       5 psi = psi[cells]
#       6
# ----> 7 mrna_per_event = get_mrna_per_event(mrna, psi, reads, intron_mtx_CI) #constitutive_sj_file)
#
# ~/psix_project/psix/psix/rnaseq_tools.py in get_mrna_per_event(mrna, psi, reads, constitutive_sj)
#      20     mrna_per_junction.index = obs_junctions
#      21
# ---> 22     reads_per_junction = (constitutive_sj.loc[obs_junctions] / mrna_per_junction).replace([np.inf, -np.inf], np.nan)
#      23     SJ_mean = reads_per_junction.mean()
#      24
#
# ~/.local/lib/python3.7/site-packages/pandas/core/frame.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    4170             limit=limit,
#    4171             regex=regex,
# -> 4172             method=method,
#    4173         )
#    4174
#
# ~/.local/lib/python3.7/site-packages/pandas/core/generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    6702                 else:  # [NA, ''] -> 0
#    6703                     new_data = self._data.replace(
# -> 6704                         to_replace=to_replace, value=value, inplace=inplace, regex=regex
#    6705                     )
#    6706             elif to_replace is None:
#
# ~/.local/lib/python3.7/site-packages/pandas/core/internals/managers.py in replace(self, value, **kwargs)
#     587     def replace(self, value, **kwargs):
#     588         assert np.ndim(value) == 0, value
# --> 589         return self.apply("replace", value=value, **kwargs)
#     590
#     591     def replace_list(self, src_list, dest_list, inplace=False, regex=False):
#
# ~/.local/lib/python3.7/site-packages/pandas/core/internals/managers.py in apply(self, f, filter, **kwargs)
#     440                 applied = b.apply(f, **kwargs)
#     441             else:
# --> 442                 applied = getattr(b, f)(**kwargs)
#     443             result_blocks = _extend_blocks(applied, result_blocks)
#     444
#
# ~/.local/lib/python3.7/site-packages/pandas/core/internals/blocks.py in replace(self, to_replace, value, inplace, filter, regex, convert)
#     785                 raise
#     786
# --> 787             assert not self._can_hold_element(value), value
#     788
#     789             # try again with a compatible block
#
# AssertionError: nan

# %%
constitutive_sj = intron_mtx_CI
obs_mrna = mrna.index[mrna.median(axis=1) >= 1]
obs_junctions = [x for x in constitutive_sj.index if x.split('_')[0] in obs_mrna]

mrna_per_junction = mrna.loc[[x.split('_')[0] for x in obs_junctions]]
mrna_per_junction.index = obs_junctions

reads_per_junction = (constitutive_sj.loc[obs_junctions] / mrna_per_junction).replace([np.inf, -np.inf], np.nan)
SJ_mean = reads_per_junction.mean()

mrna_events = (reads/(SJ_mean * (1+psi)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/pandas/core/internals/blocks.py in replace(self, to_replace, value, inplace, filter, regex, convert)
#     773         try:
# --> 774             blocks = self.putmask(mask, value, inplace=inplace)
#     775             # Note: it is _not_ the case that self._can_hold_element(value)
#
# ~/.local/lib/python3.7/site-packages/pandas/core/internals/blocks.py in putmask(self, mask, new, align, inplace, axis, transpose)
#    1675
# -> 1676         new_values[mask] = new
#    1677         return [self.make_block(values=new_values)]
#
# ~/.local/lib/python3.7/site-packages/pandas/core/arrays/sparse/array.py in __setitem__(self, key, value)
#     460         msg = "SparseArray does not support item assignment via setitem"
# --> 461         raise TypeError(msg)
#     462
#
# TypeError: SparseArray does not support item assignment via setitem
#
# During handling of the above exception, another exception occurred:
#
# AssertionError                            Traceback (most recent call last)
# <ipython-input-24-8186032bf495> in <module>
#       6 mrna_per_junction.index = obs_junctions
#       7
# ----> 8 reads_per_junction = (constitutive_sj.loc[obs_junctions] / mrna_per_junction).replace([np.inf, -np.inf], np.nan)
#       9 SJ_mean = reads_per_junction.mean()
#      10
#
# ~/.local/lib/python3.7/site-packages/pandas/core/frame.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    4170             limit=limit,
#    4171             regex=regex,
# -> 4172             method=method,
#    4173         )
#    4174
#
# ~/.local/lib/python3.7/site-packages/pandas/core/generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    6702                 else:  # [NA, ''] -> 0
#    6703                     new_data = self._data.replace(
# -> 6704                         to_replace=to_replace, value=value, inplace=inplace, regex=regex
#    6705                     )
#    6706             elif to_replace is None:
#
# ~/.local/lib/python3.7/site-packages/pandas/core/internals/managers.py in replace(self, value, **kwargs)
#     587     def replace(self, value, **kwargs):
#     588         assert np.ndim(value) == 0, value
# --> 589         return self.apply("replace", value=value, **kwargs)
#     590
#     591     def replace_list(self, src_list, dest_list, inplace=False, regex=False):
#
# ~/.local/lib/python3.7/site-packages/pandas/core/internals/managers.py in apply(self, f, filter, **kwargs)
#     440                 applied = b.apply(f, **kwargs)
#     441             else:
# --> 442                 applied = getattr(b, f)(**kwargs)
#     443             result_blocks = _extend_blocks(applied, result_blocks)
#     444
#
# ~/.local/lib/python3.7/site-packages/pandas/core/internals/blocks.py in replace(self, to_replace, value, inplace, filter, regex, convert)
#     785                 raise
#     786
# --> 787             assert not self._can_hold_element(value), value
#     788
#     789             # try again with a compatible block
#
# AssertionError: nan

# %%
pd.DataFrame((constitutive_sj.loc[obs_junctions] / mrna_per_junction)).replace([np.inf, -np.inf], np.nan)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/pandas/core/internals/blocks.py in replace(self, to_replace, value, inplace, filter, regex, convert)
#     773         try:
# --> 774             blocks = self.putmask(mask, value, inplace=inplace)
#     775             # Note: it is _not_ the case that self._can_hold_element(value)
#
# ~/.local/lib/python3.7/site-packages/pandas/core/internals/blocks.py in putmask(self, mask, new, align, inplace, axis, transpose)
#    1675
# -> 1676         new_values[mask] = new
#    1677         return [self.make_block(values=new_values)]
#
# ~/.local/lib/python3.7/site-packages/pandas/core/arrays/sparse/array.py in __setitem__(self, key, value)
#     460         msg = "SparseArray does not support item assignment via setitem"
# --> 461         raise TypeError(msg)
#     462
#
# TypeError: SparseArray does not support item assignment via setitem
#
# During handling of the above exception, another exception occurred:
#
# AssertionError                            Traceback (most recent call last)
# <ipython-input-30-99dfda68f62f> in <module>
# ----> 1 pd.DataFrame((constitutive_sj.loc[obs_junctions] / mrna_per_junction)).replace([np.inf, -np.inf], np.nan)
#
# ~/.local/lib/python3.7/site-packages/pandas/core/frame.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    4170             limit=limit,
#    4171             regex=regex,
# -> 4172             method=method,
#    4173         )
#    4174
#
# ~/.local/lib/python3.7/site-packages/pandas/core/generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    6702                 else:  # [NA, ''] -> 0
#    6703                     new_data = self._data.replace(
# -> 6704                         to_replace=to_replace, value=value, inplace=inplace, regex=regex
#    6705                     )
#    6706             elif to_replace is None:
#
# ~/.local/lib/python3.7/site-packages/pandas/core/internals/managers.py in replace(self, value, **kwargs)
#     587     def replace(self, value, **kwargs):
#     588         assert np.ndim(value) == 0, value
# --> 589         return self.apply("replace", value=value, **kwargs)
#     590
#     591     def replace_list(self, src_list, dest_list, inplace=False, regex=False):
#
# ~/.local/lib/python3.7/site-packages/pandas/core/internals/managers.py in apply(self, f, filter, **kwargs)
#     440                 applied = b.apply(f, **kwargs)
#     441             else:
# --> 442                 applied = getattr(b, f)(**kwargs)
#     443             result_blocks = _extend_blocks(applied, result_blocks)
#     444
#
# ~/.local/lib/python3.7/site-packages/pandas/core/internals/blocks.py in replace(self, to_replace, value, inplace, filter, regex, convert)
#     785                 raise
#     786
# --> 787             assert not self._can_hold_element(value), value
#     788
#     789             # try again with a compatible block
#
# AssertionError: nan

# %%
obs_junctions
# Out:
# ['AI413582_2_CI',
#  'AI413582_3_CI',
#  'Aacs_11_CI',
#  'Aacs_12_CI',
#  'Aacs_4_CI',
#  'Aacs_5_CI',
#  'Aagab_5_CI',
#  'Aagab_6_CI',
#  'Aagab_4_CI',
#  'Aagab_7_CI',
#  'Aarsd1_2_CI',
#  'Aarsd1_4_CI',
#  'Aarsd1_11_CI',
#  'Abcc5_3_CI',
#  'Abcd3_16_CI',
#  'Abcd3_17_CI',
#  'Abce1_2_CI',
#  'Abce1_3_CI',
#  'Abce1_10_CI',
#  'Abce1_11_CI',
#  'Abcf1_4_CI',
#  'Abcf2_4_CI',
#  'Abcf2_5_CI',
#  'Abcf3_3_CI',
#  'Abcf3_4_CI',
#  'Abcf3_9_CI',
#  'Abcf3_10_CI',
#  'Abhd12_3_CI',
#  'Abhd12_4_CI',
#  'Abhd12_7_CI',
#  'Abhd12_8_CI',
#  'Abhd12_12_CI',
#  'Abhd14a_1_CI',
#  'Abhd16a_10_CI',
#  'Abhd16a_11_CI',
#  'Abhd16a_3_CI',
#  'Abhd8_3_CI',
#  'Abhd8_4_CI',
#  'Abi1_3_CI',
#  'Abi1_4_CI',
#  'Acaa1a_1_CI',
#  'Acadm_3_CI',
#  'Acat1_2_CI',
#  'Acat1_3_CI',
#  'Acat1_6_CI',
#  'Acat1_7_CI',
#  'Acat1_10_CI',
#  'Acat1_11_CI',
#  'Acat1_8_CI',
#  'Acat1_9_CI',
#  'Acat2_2_CI',
#  'Acat2_3_CI',
#  'Acd_8_CI',
#  'Acd_9_CI',
#  'Acd_7_CI',
#  'Acd_6_CI',
#  'Acd_5_CI',
#  'Acly_9_CI',
#  'Acly_10_CI',
#  'Acly_7_CI',
#  'Acly_8_CI',
#  'Aco2_2_CI',
#  'Aco2_15_CI',
#  'Aco2_16_CI',
#  'Aco2_7_CI',
#  'Aco2_8_CI',
#  'Aco2_3_CI',
#  'Aco2_4_CI',
#  'Aco2_11_CI',
#  'Aco2_12_CI',
#  'Acot7_5_CI',
#  'Acot7_6_CI',
#  'Acot7_4_CI',
#  'Acp2_1_CI',
#  'Actr10_6_CI',
#  'Actr10_7_CI',
#  'Actr10_1_CI',
#  'Actr1a_8_CI',
#  'Actr1a_9_CI',
#  'Actr1b_1_CI',
#  'Actr2_5_CI',
#  'Actr2_6_CI',
#  'Actr2_7_CI',
#  'Actr2_8_CI',
#  'Actr3_1_CI',
#  'Actr8_8_CI',
#  'Actr8_9_CI',
#  'Adar_8_CI',
#  'Adar_9_CI',
#  'Adgrg1_6_CI',
#  'Adgrg1_7_CI',
#  'Adh5_2_CI',
#  'Adh5_3_CI',
#  'Adipor1_5_CI',
#  'Adipor1_6_CI',
#  'Adprh_2_CI',
#  'Adprh_3_CI',
#  'Adprhl2_2_CI',
#  'Adprhl2_3_CI',
#  'Adrm1_7_CI',
#  'Adrm1_8_CI',
#  'Aes_3_CI',
#  'Aes_1_CI',
#  'Aes_5_CI',
#  'Agk_2_CI',
#  'Agk_10_CI',
#  'Agpat4_2_CI',
#  'Agrn_17_CI',
#  'Agrn_18_CI',
#  'Agrn_9_CI',
#  'Agrn_10_CI',
#  'Agrn_2_CI',
#  'Agrn_3_CI',
#  'Ahcyl1_1_CI',
#  'Ahi1_1_CI',
#  'Ahsa1_2_CI',
#  'Ahsa1_3_CI',
#  'Aig1_1_CI',
#  'Aimp1_1_CI',
#  'Aimp2_2_CI',
#  'Ak2_3_CI',
#  'Ak2_4_CI',
#  'Ak2_1_CI',
#  'Akap8l_12_CI',
#  'Akap8l_13_CI',
#  'Akirin1_2_CI',
#  'Akr1a1_1_CI',
#  'Akr1a1_2_CI',
#  'Akr7a5_4_CI',
#  'Akr7a5_5_CI',
#  'Akr7a5_3_CI',
#  'Alad_5_CI',
#  'Alad_6_CI',
#  'Alkbh6_4_CI',
#  'Alkbh6_1_CI',
#  'Alkbh6_3_CI',
#  'Amn1_2_CI',
#  'Amn1_1_CI',
#  'Ampd2_15_CI',
#  'Ampd2_16_CI',
#  'Ampd2_6_CI',
#  'Ampd2_7_CI',
#  'Ampd2_4_CI',
#  'Ampd2_5_CI',
#  'Amph_16_CI',
#  'Amph_1_CI',
#  'Anapc2_3_CI',
#  'Ankmy2_2_CI',
#  'Ankra2_3_CI',
#  'Ankra2_4_CI',
#  'Ankrd12_1_CI',
#  'Ankrd13d_1_CI',
#  'Ankrd46_2_CI',
#  'Ankrd46_4_CI',
#  'Ap1b1_14_CI',
#  'Ap1b1_15_CI',
#  'Ap1b1_2_CI',
#  'Ap1s2_1_CI',
#  'Ap1s2_2_CI',
#  'Ap2a1_2_CI',
#  'Ap2a2_1_CI',
#  'Ap2a2_2_CI',
#  'Ap2m1_4_CI',
#  'Ap2m1_5_CI',
#  'Ap2m1_7_CI',
#  'Ap2m1_1_CI',
#  'Ap2m1_2_CI',
#  'Ap2s1_1_CI',
#  'Ap3b2_5_CI',
#  'Ap3b2_6_CI',
#  'Ap3b2_1_CI',
#  'Ap3b2_2_CI',
#  'Ap3d1_9_CI',
#  'Ap3d1_10_CI',
#  'Ap3d1_18_CI',
#  'Ap3d1_17_CI',
#  'Ap3d1_20_CI',
#  'Ap3d1_21_CI',
#  'Ap3d1_8_CI',
#  'Ap3d1_22_CI',
#  'Ap3d1_23_CI',
#  'Ap3d1_29_CI',
#  'Ap3d1_30_CI',
#  'Ap3d1_16_CI',
#  'Ap3s1_4_CI',
#  'Ap3s1_1_CI',
#  'Ap3s2_3_CI',
#  'Ap3s2_4_CI',
#  'Ap3s2_5_CI',
#  'Ap4s1_3_CI',
#  'Ap4s1_4_CI',
#  'Apba1_5_CI',
#  'Apba1_6_CI',
#  'Apeh_3_CI',
#  'Api5_13_CI',
#  'Api5_5_CI',
#  'Api5_6_CI',
#  'Api5_7_CI',
#  'Aplp1_3_CI',
#  'Aplp1_4_CI',
#  'Aplp1_5_CI',
#  'Aplp2_6_CI',
#  'Aplp2_7_CI',
#  'Apoo_7_CI',
#  'Apopt1_1_CI',
#  'App_3_CI',
#  'App_4_CI',
#  'Aprt_3_CI',
#  'Arcn1_2_CI',
#  'Arcn1_3_CI',
#  'Arf4_1_CI',
#  'Arfgap1_2_CI',
#  'Arfgap2_5_CI',
#  'Arfgap2_6_CI',
#  'Arfgap2_8_CI',
#  'Arfrp1_5_CI',
#  'Arfrp1_1_CI',
#  'Arfrp1_2_CI',
#  'Arfrp1_3_CI',
#  'Arhgap1_8_CI',
#  'Arhgap1_4_CI',
#  'Arhgap1_9_CI',
#  'Arhgap1_10_CI',
#  'Arhgap1_2_CI',
#  'Arhgdia_3_CI',
#  'Arhgdig_3_CI',
#  'Arl16_3_CI',
#  'Arl16_1_CI',
#  'Arl16_2_CI',
#  'Arl2_2_CI',
#  'Arl2_3_CI',
#  'Arl2bp_2_CI',
#  'Arl3_3_CI',
#  'Arl3_4_CI',
#  'Arl6ip1_2_CI',
#  'Arl6ip1_1_CI',
#  'Armc8_1_CI',
#  'Armc8_6_CI',
#  'Armc8_7_CI',
#  'Armc8_9_CI',
#  'Armcx2_2_CI',
#  'Arpc1a_2_CI',
#  'Arpc3_3_CI',
#  'Arpc5l_2_CI',
#  'Arrdc3_2_CI',
#  'Arvcf_10_CI',
#  'Arvcf_11_CI',
#  'Arvcf_12_CI',
#  'Ash2l_5_CI',
#  'Ash2l_6_CI',
#  'Ash2l_4_CI',
#  'Ash2l_10_CI',
#  'Ash2l_11_CI',
#  'Ash2l_1_CI',
#  'Ash2l_8_CI',
#  'Ash2l_12_CI',
#  'Asna1_2_CI',
#  'Atad1_2_CI',
#  'Atad1_3_CI',
#  'Atad1_7_CI',
#  'Atad1_8_CI',
#  'Atad1_9_CI',
#  'Atad3a_4_CI',
#  'Atad3a_13_CI',
#  'Atad3a_14_CI',
#  'Atad3a_5_CI',
#  'Atad3a_6_CI',
#  'Atad3a_7_CI',
#  'Atcay_2_CI',
#  'Atcay_11_CI',
#  'Atcay_12_CI',
#  'Atcay_10_CI',
#  'Ate1_3_CI',
#  'Ate1_1_CI',
#  'Ate1_2_CI',
#  'Atg13_10_CI',
#  'Atg13_11_CI',
#  'Atg13_2_CI',
#  'Atg13_12_CI',
#  'Atg3_8_CI',
#  'Atg3_3_CI',
#  'Atg3_7_CI',
#  'Atg4b_1_CI',
#  'Atg4b_2_CI',
#  'Atl1_13_CI',
#  'Atl1_14_CI',
#  'Atl1_7_CI',
#  'Atl1_8_CI',
#  'Atl1_5_CI',
#  'Atl1_6_CI',
#  'Atox1_3_CI',
#  'Atox1_1_CI',
#  'Atp13a2_11_CI',
#  'Atp13a2_12_CI',
#  'Atp1b3_4_CI',
#  'Atp1b3_5_CI',
#  'Atp1b3_3_CI',
#  'Atp1b3_6_CI',
#  'Atp5g1_2_CI',
#  'Atp5g1_3_CI',
#  'Atp5h_1_CI',
#  'Atp5h_2_CI',
#  'Atp5k_1_CI',
#  'Atp6v0a1_1_CI',
#  'Atp6v0a1_2_CI',
#  'Atp6v1b2_12_CI',
#  'Atp6v1b2_13_CI',
#  'Atp6v1c1_8_CI',
#  'Atp6v1c1_9_CI',
#  'Atp6v1c1_3_CI',
#  'Atp6v1c1_1_CI',
#  'Atp6v1c1_5_CI',
#  'Atp6v1d_5_CI',
#  'Atp6v1d_6_CI',
#  'Atp6v1d_7_CI',
#  'Atp6v1d_8_CI',
#  'Atp6v1g1_2_CI',
#  'Atp6v1h_1_CI',
#  'Atp6v1h_2_CI',
#  'Atp9a_1_CI',
#  'Atrn_22_CI',
#  'Atrn_23_CI',
#  'Atrn_20_CI',
#  'Atrn_21_CI',
#  'Atrn_12_CI',
#  'Atrn_13_CI',
#  'Atrn_2_CI',
#  'Atrn_3_CI',
#  'Atxn10_6_CI',
#  'Atxn10_7_CI',
#  'Atxn10_1_CI',
#  'Auh_1_CI',
#  'Aup1_4_CI',
#  'Aup1_6_CI',
#  'Aup1_7_CI',
#  'Aup1_9_CI',
#  'Aup1_10_CI',
#  'Aup1_5_CI',
#  'Aup1_2_CI',
#  'Aup1_3_CI',
#  'Azin1_1_CI',
#  'B4galnt1_8_CI',
#  'B4galnt1_5_CI',
#  'B4galnt1_6_CI',
#  'B4galnt1_7_CI',
#  'BC004004_5_CI',
#  'BC004004_6_CI',
#  'BC004004_1_CI',
#  'BC004004_2_CI',
#  'BC005624_5_CI',
#  'BC005624_6_CI',
#  'BC031181_2_CI',
#  'Babam1_7_CI',
#  'Babam1_3_CI',
#  'Bag1_2_CI',
#  'Bag1_3_CI',
#  'Bag1_4_CI',
#  'Bap1_6_CI',
#  'Bap1_14_CI',
#  'Bap1_15_CI',
#  'Bap1_5_CI',
#  'Bap1_3_CI',
#  'Bap1_4_CI',
#  'Bap1_9_CI',
#  'Bap1_10_CI',
#  'Bbs4_2_CI',
#  'Bbs4_7_CI',
#  'Bbs4_8_CI',
#  'Bbs4_9_CI',
#  'Bbs4_13_CI',
#  'Bbs4_14_CI',
#  'Bcap31_5_CI',
#  'Bcap31_6_CI',
#  'Bcap31_7_CI',
#  'Bcas2_4_CI',
#  'Bcas2_5_CI',
#  'Bclaf1_5_CI',
#  'Bclaf1_8_CI',
#  'Becn1_1_CI',
#  'Begain_2_CI',
#  'Bex2_2_CI',
#  'Bfar_3_CI',
#  'Bin1_10_CI',
#  'Bloc1s6_2_CI',
#  'Bnip3_2_CI',
#  'Bnip3_3_CI',
#  'Bnip3_4_CI',
#  'Bod1_2_CI',
#  'Bop1_14_CI',
#  'Bop1_15_CI',
#  'Bpnt1_1_CI',
#  'Brd8_15_CI',
#  'Brd8_16_CI',
#  'Brd8_1_CI',
#  'Brd8_6_CI',
#  'Brd8_7_CI',
#  'Brd8_5_CI',
#  'Brd8_14_CI',
#  'Brd8_10_CI',
#  'Bri3bp_1_CI',
#  'Brk1_2_CI',
#  'Bscl2_2_CI',
#  'Bscl2_6_CI',
#  'Bscl2_7_CI',
#  'Bzw2_9_CI',
#  'Bzw2_10_CI',
#  'Bzw2_11_CI',
#  'C1qbp_2_CI',
#  'Cacfd1_1_CI',
#  'Cacna2d3_31_CI',
#  'Cacna2d3_32_CI',
#  'Cacna2d3_24_CI',
#  'Cacna2d3_25_CI',
#  'Cacna2d3_12_CI',
#  'Cacna2d3_13_CI',
#  'Cacna2d3_34_CI',
#  'Cacna2d3_35_CI',
#  'Cacna2d3_18_CI',
#  'Cacna2d3_19_CI',
#  'Cacna2d3_28_CI',
#  'Cacna2d3_29_CI',
#  'Cacnb3_4_CI',
#  'Cacnb3_5_CI',
#  'Cacnb3_7_CI',
#  'Cacnb3_8_CI',
#  'Cadm1_5_CI',
#  'Cadm1_6_CI',
#  'Calm2_4_CI',
#  'Calm2_5_CI',
#  'Calr_6_CI',
#  'Calr_7_CI',
#  'Calr_1_CI',
#  'Camk2b_5_CI',
#  'Camk2g_15_CI',
#  'Camk2g_16_CI',
#  'Camk2g_6_CI',
#  'Camk2g_9_CI',
#  'Camk2g_10_CI',
#  'Camk2g_14_CI',
#  'Camk2g_5_CI',
#  'Canx_6_CI',
#  'Canx_7_CI',
#  'Canx_11_CI',
#  'Canx_12_CI',
#  'Canx_13_CI',
#  'Capn10_3_CI',
#  'Capza2_2_CI',
#  'Capza2_3_CI',
#  'Car11_3_CI',
#  'Car11_4_CI',
#  'Car11_5_CI',
#  'Car11_6_CI',
#  'Car11_1_CI',
#  'Car11_2_CI',
#  'Car11_7_CI',
#  'Car11_8_CI',
#  'Carhsp1_2_CI',
#  'Carhsp1_3_CI',
#  'Cars_2_CI',
#  'Cars_3_CI',
#  'Casp3_2_CI',
#  'Cby1_2_CI',
#  'Ccar2_10_CI',
#  'Ccar2_11_CI',
#  'Ccar2_12_CI',
#  'Ccar2_13_CI',
#  'Ccdc124_3_CI',
#  'Ccdc124_4_CI',
#  'Ccdc32_1_CI',
#  'Ccdc92_1_CI',
#  'Ccnc_7_CI',
#  'Ccnc_8_CI',
#  'Ccnc_2_CI',
#  'Ccndbp1_7_CI',
#  'Ccndbp1_2_CI',
#  'Ccnl2_2_CI',
#  'Ccnl2_6_CI',
#  'Ccnl2_7_CI',
#  'Ccnl2_5_CI',
#  'Ccnt2_7_CI',
#  'Ccnt2_8_CI',
#  'Ccnt2_4_CI',
#  'Cct2_10_CI',
#  'Cct2_11_CI',
#  'Cct4_2_CI',
#  'Cct4_7_CI',
#  'Cct4_8_CI',
#  'Cd164_3_CI',
#  'Cd164_4_CI',
#  'Cd164_1_CI',
#  'Cd200_3_CI',
#  'Cd200_4_CI',
#  'Cd47_5_CI',
#  'Cd47_6_CI',
#  'Cd81_2_CI',
#  'Cd81_3_CI',
#  'Cd99l2_5_CI',
#  'Cd99l2_3_CI',
#  'Cd99l2_4_CI',
#  'Cdc123_1_CI',
#  'Cdc123_3_CI',
#  'Cdc123_4_CI',
#  'Cdc16_1_CI',
#  'Cdc23_2_CI',
#  'Cdc23_3_CI',
#  'Cdc23_10_CI',
#  'Cdc23_11_CI',
#  'Cdc23_4_CI',
#  'Cdc23_5_CI',
#  'Cdc23_1_CI',
#  'Cdc37_2_CI',
#  'Cdc42se2_2_CI',
#  'Cdc5l_3_CI',
#  'Cdh13_2_CI',
#  'Cdh13_3_CI',
#  'Cdh13_4_CI',
#  'Cdk11b_13_CI',
#  'Cdk11b_14_CI',
#  'Cdk11b_3_CI',
#  'Cdk11b_9_CI',
#  'Cdk11b_10_CI',
#  'Cdk16_9_CI',
#  'Cdk16_11_CI',
#  'Cdk16_7_CI',
#  'Cdk16_8_CI',
#  'Cdk16_1_CI',
#  'Cdk16_5_CI',
#  'Cdk5_4_CI',
#  'Cdk5_5_CI',
#  'Cdkn2aipnl_2_CI',
#  'Cdo1_3_CI',
#  'Cdo1_4_CI',
#  'Celf1_5_CI',
#  'Celf1_7_CI',
#  'Celf1_8_CI',
#  'Celf5_1_CI',
#  'Celf6_5_CI',
#  'Celf6_2_CI',
#  'Celf6_6_CI',
#  'Cers5_1_CI',
#  'Cetn3_2_CI',
#  'Cfap20_2_CI',
#  'Cfap20_3_CI',
#  'Cfap20_4_CI',
#  'Cfap20_5_CI',
#  'Cfap36_2_CI',
#  'Cfdp1_3_CI',
#  'Chchd10_2_CI',
#  'Chchd2_2_CI',
#  'Chchd2_3_CI',
#  'Chchd3_1_CI',
#  'Chga_3_CI',
#  'Chga_4_CI',
#  'Chga_1_CI',
#  'Chid1_2_CI',
#  'Chid1_4_CI',
#  'Chid1_5_CI',
#  'Chid1_6_CI',
#  'Chmp2a_2_CI',
#  'Chordc1_4_CI',
#  'Chordc1_5_CI',
#  'Chordc1_1_CI',
#  'Chst10_1_CI',
#  'Ciao1_2_CI',
#  'Ciao1_3_CI',
#  'Cinp_2_CI',
#  'Cinp_3_CI',
#  'Cinp_4_CI',
#  'Cirbp_2_CI',
#  'Clasp2_28_CI',
#  'Clasp2_29_CI',
#  'Clasp2_12_CI',
#  'Clasp2_13_CI',
#  'Clasp2_19_CI',
#  'Clasp2_17_CI',
#  'Clasp2_18_CI',
#  'Clasp2_14_CI',
#  'Clasp2_22_CI',
#  'Clasp2_23_CI',
#  'Clasrp_18_CI',
#  'Clasrp_19_CI',
#  'Clasrp_17_CI',
#  'Clk1_9_CI',
#  'Clk1_10_CI',
#  'Clk1_5_CI',
#  'Clk1_6_CI',
#  'Clk1_7_CI',
#  'Clns1a_5_CI',
#  'Clns1a_6_CI',
#  'Clns1a_1_CI',
#  'Clpp_4_CI',
#  'Clpp_5_CI',
#  'Clpp_2_CI',
#  'Clptm1_5_CI',
#  'Clptm1_6_CI',
#  'Clptm1_3_CI',
#  'Clptm1_13_CI',
#  'Clptm1l_11_CI',
#  'Clptm1l_12_CI',
#  'Clptm1l_15_CI',
#  'Clptm1l_16_CI',
#  'Clstn1_8_CI',
#  'Clstn1_9_CI',
#  'Clstn1_1_CI',
#  'Clta_1_CI',
#  'Clta_2_CI',
#  'Clvs1_1_CI',
#  'Cmas_2_CI',
#  'Cmas_6_CI',
#  'Cmas_7_CI',
#  'Cmas_4_CI',
#  'Cmip_8_CI',
#  'Cmip_9_CI',
#  'Cmip_4_CI',
#  'Cmip_5_CI',
#  'Cmip_16_CI',
#  'Cmip_17_CI',
#  'Cmpk1_5_CI',
#  'Cnih1_3_CI',
#  'Cnih2_2_CI',
#  'Cnih2_3_CI',
#  'Cnot10_17_CI',
#  'Cnot10_18_CI',
#  'Cnot10_3_CI',
#  'Cnot10_1_CI',
#  'Cnot10_5_CI',
#  'Cnot10_12_CI',
#  'Cnot10_13_CI',
#  'Cnot10_9_CI',
#  'Cnot10_10_CI',
#  'Cnot10_8_CI',
#  'Cnpy2_2_CI',
#  'Colgalt1_10_CI',
#  'Colgalt1_11_CI',
#  'Colgalt1_5_CI',
#  'Colgalt1_6_CI',
#  'Commd4_5_CI',
#  'Commd4_6_CI',
#  'Commd7_2_CI',
#  'Commd9_2_CI',
#  'Commd9_3_CI',
#  'Comt_2_CI',
#  'Comt_1_CI',
#  'Comtd1_5_CI',
#  'Copa_3_CI',
#  'Copa_1_CI',
#  'Copa_13_CI',
#  'Copa_14_CI',
#  'Copa_20_CI',
#  'Copa_21_CI',
#  'Copa_11_CI',
#  'Copb1_2_CI',
#  'Copb1_3_CI',
#  'Copb2_19_CI',
#  'Copb2_20_CI',
#  'Copg1_2_CI',
#  'Copg1_3_CI',
#  'Copg1_1_CI',
#  'Coprs_2_CI',
#  'Cops2_3_CI',
#  'Cops2_4_CI',
#  'Cops2_7_CI',
#  'Cops2_2_CI',
#  'Cops2_8_CI',
#  'Cops2_10_CI',
#  'Cops4_4_CI',
#  'Cops5_2_CI',
#  'Cops6_3_CI',
#  'Copz1_6_CI',
#  'Copz1_7_CI',
#  'Copz1_8_CI',
#  'Copz1_4_CI',
#  'Copz1_5_CI',
#  'Coro1b_2_CI',
#  'Coro1c_1_CI',
#  'Coro7_5_CI',
#  'Coro7_6_CI',
#  'Cotl1_2_CI',
#  'Cox20_2_CI',
#  'Cox20_3_CI',
#  'Cox5a_2_CI',
#  'Cox5a_3_CI',
#  'Cox5a_1_CI',
#  'Cox6a1_2_CI',
#  'Cox7a2_2_CI',
#  'Cpe_2_CI',
#  'Cpsf1_3_CI',
#  'Cpsf1_4_CI',
#  'Cpsf1_23_CI',
#  'Cpsf1_24_CI',
#  'Cpsf1_22_CI',
#  'Cpsf1_31_CI',
#  'Cpsf1_32_CI',
#  'Cpsf1_8_CI',
#  'Cpsf1_9_CI',
#  'Cpsf1_5_CI',
#  'Cpsf3_4_CI',
#  'Cpsf3_5_CI',
#  'Cpsf3_12_CI',
#  'Cpsf3_13_CI',
#  'Crbn_4_CI',
#  'Crcp_1_CI',
#  'Crcp_2_CI',
#  'Creld1_4_CI',
#  'Creld1_5_CI',
#  'Creld1_8_CI',
#  'Creld1_9_CI',
#  'Crmp1_1_CI',
#  'Crtc1_9_CI',
#  'Crtc1_10_CI',
#  'Crtc1_12_CI',
#  'Crtc1_13_CI',
#  'Crtc1_8_CI',
#  'Crtc1_6_CI',
#  'Crtc1_2_CI',
#  'Crtc1_3_CI',
#  'Csde1_8_CI',
#  'Csde1_9_CI',
#  'Cse1l_1_CI',
#  'Cse1l_12_CI',
#  'Cse1l_13_CI',
#  'Cse1l_6_CI',
#  'Cse1l_7_CI',
#  'Cse1l_4_CI',
#  'Cse1l_5_CI',
#  'Cse1l_3_CI',
#  'Cse1l_2_CI',
#  'Csnk1a1_3_CI',
#  'Csnk1a1_4_CI',
#  'Csnk1d_2_CI',
#  'Csnk1d_3_CI',
#  'Cspg5_2_CI',
#  'Csrnp3_1_CI',
#  'Csrp2_3_CI',
#  'Csrp2_4_CI',
#  'Cstf3_17_CI',
#  'Cstf3_18_CI',
#  'Cstf3_19_CI',
#  'Cstf3_15_CI',
#  'Cstf3_16_CI',
#  'Ctc1_9_CI',
#  'Ctc1_10_CI',
#  'Ctc1_8_CI',
#  'Ctc1_11_CI',
#  'Ctc1_7_CI',
#  'Ctc1_13_CI',
#  'Ctc1_14_CI',
#  'Ctc1_1_CI',
#  'Ctc1_2_CI',
#  'Ctc1_15_CI',
#  'Ctc1_16_CI',
#  'Ctnna2_3_CI',
#  'Ctnnbip1_2_CI',
#  'Ctps_11_CI',
#  'Ctps_12_CI',
#  'Ctps_17_CI',
#  'Ctps_18_CI',
#  'Ctps_9_CI',
#  'Ctps_10_CI',
#  'Ctps_3_CI',
#  'Ctps_6_CI',
#  'Ctsf_3_CI',
#  'Ctsf_4_CI',
#  'Ctsf_10_CI',
#  'Ctsf_2_CI',
#  'Ctsf_11_CI',
#  'Ctsf_12_CI',
#  'Cttn_7_CI',
#  'Cttn_14_CI',
#  'Cttn_15_CI',
#  'Cttn_8_CI',
#  'Cttn_13_CI',
#  'Cttn_5_CI',
#  'Cttn_6_CI',
#  'Cttn_10_CI',
#  'Cuedc2_7_CI',
#  'Cuedc2_4_CI',
#  'Cuedc2_5_CI',
#  'Cuedc2_3_CI',
#  'Cul2_9_CI',
#  'Cul2_10_CI',
#  'Cuta_3_CI',
#  'Cx3cl1_2_CI',
#  'Cyb5a_2_CI',
#  'Cyb5b_3_CI',
#  'Cyb5b_4_CI',
#  'Cyc1_2_CI',
#  'Cyc1_3_CI',
#  'D8Ertd738e_2_CI',
#  'Dbi_2_CI',
#  'Dbn1_4_CI',
#  'Dbn1_5_CI',
#  'Dbnl_2_CI',
#  'Dbnl_3_CI',
#  'Dcaf7_5_CI',
#  'Dcaf7_6_CI',
#  'Dcaf7_1_CI',
#  'Dcaf8_2_CI',
#  'Dcps_4_CI',
#  'Dcps_3_CI',
#  'Dctn2_12_CI',
#  'Dctn2_13_CI',
#  'Dctn2_1_CI',
#  'Dctn2_2_CI',
#  'Dctn2_10_CI',
#  'Dctn2_11_CI',
#  'Dctn2_8_CI',
#  'Dctn2_9_CI',
#  'Dctn2_7_CI',
#  'Dctn2_5_CI',
#  'Dctn2_6_CI',
#  'Dctn4_3_CI',
#  'Dctn4_4_CI',
#  'Dctn5_3_CI',
#  'Dctn5_4_CI',
#  'Dctn5_5_CI',
#  'Dctn6_1_CI',
#  'Dcun1d4_3_CI',
#  'Dcun1d4_1_CI',
#  'Dcun1d4_2_CI',
#  'Dcun1d5_3_CI',
#  'Dcun1d5_4_CI',
#  'Dcun1d5_6_CI',
#  'Dcun1d5_7_CI',
#  'Ddb1_9_CI',
#  'Ddb1_10_CI',
#  'Ddb1_23_CI',
#  'Ddb1_24_CI',
#  'Ddost_2_CI',
#  'Ddost_3_CI',
#  'Ddost_7_CI',
#  'Ddost_8_CI',
#  'Ddx1_23_CI',
#  'Ddx1_24_CI',
#  'Ddx1_3_CI',
#  'Ddx1_4_CI',
#  'Ddx1_18_CI',
#  'Ddx1_19_CI',
#  'Ddx1_5_CI',
#  'Ddx1_6_CI',
#  'Ddx1_9_CI',
#  'Ddx1_10_CI',
#  'Ddx39_4_CI',
#  'Ddx39_5_CI',
#  'Ddx42_4_CI',
#  'Ddx42_5_CI',
#  'Ddx5_3_CI',
#  'Ddx5_4_CI',
#  'Dek_4_CI',
#  'Dek_2_CI',
#  'Dennd6b_7_CI',
#  'Dennd6b_8_CI',
#  'Dennd6b_6_CI',
#  'Dennd6b_9_CI',
#  'Dennd6b_13_CI',
#  'Dennd6b_11_CI',
#  'Dennd6b_12_CI',
#  'Dennd6b_15_CI',
#  'Dennd6b_16_CI',
#  'Denr_2_CI',
#  'Denr_5_CI',
#  'Denr_1_CI',
#  'Derl1_6_CI',
#  'Desi1_3_CI',
#  'Desi1_4_CI',
#  'Desi1_2_CI',
#  'Desi1_5_CI',
#  'Dgat1_7_CI',
#  'Dhps_3_CI',
#  'Dhps_4_CI',
#  'Dhrs1_4_CI',
#  'Dhrs1_5_CI',
#  'Diablo_2_CI',
#  'Diablo_3_CI',
#  'Diablo_1_CI',
#  'Disp2_5_CI',
#  'Dlat_8_CI',
#  'Dlat_9_CI',
#  'Dlat_10_CI',
#  'Dlat_11_CI',
#  'Dlst_2_CI',
#  'Dlst_11_CI',
#  'Dlst_12_CI',
#  'Dmtn_4_CI',
#  'Dmtn_5_CI',
#  'Dmxl2_2_CI',
#  'Dmxl2_3_CI',
#  'Dnaja2_5_CI',
#  'Dnaja2_6_CI',
#  'Dnajb11_2_CI',
#  'Dnajb9_2_CI',
#  'Dnajc10_13_CI',
#  'Dnajc10_14_CI',
#  'Dnajc10_11_CI',
#  'Dnajc10_12_CI',
#  'Dnajc11_3_CI',
#  'Dnajc15_2_CI',
#  'Dnajc15_3_CI',
#  'Dnajc15_4_CI',
#  'Dnajc15_5_CI',
#  'Dnajc5_1_CI',
#  'Dnajc7_2_CI',
#  'Dnajc7_1_CI',
#  'Dnajc8_1_CI',
#  'Dnajc9_2_CI',
#  'Dnal4_2_CI',
#  'Dnal4_3_CI',
#  'Dnm1l_9_CI',
#  'Dnm1l_10_CI',
#  'Dnm1l_11_CI',
#  'Dnm1l_14_CI',
#  'Dolpp1_3_CI',
#  'Dolpp1_1_CI',
#  'Dolpp1_4_CI',
#  'Dpf2_6_CI',
#  'Dpf2_7_CI',
#  'Dpp6_18_CI',
#  'Dpp6_19_CI',
#  'Dpy30_3_CI',
#  'Drg1_3_CI',
#  'Drg1_6_CI',
#  'Drg1_7_CI',
#  'Drg1_4_CI',
#  'Drg1_5_CI',
#  'Drg1_8_CI',
#  'Drg1_2_CI',
#  'Drg2_11_CI',
#  'Drg2_12_CI',
#  'Dscr3_5_CI',
#  'Dscr3_6_CI',
#  'Dscr3_7_CI',
#  'Dstn_2_CI',
#  'Dtd1_2_CI',
#  'Dtna_4_CI',
#  'Dtna_5_CI',
#  'Dtnbp1_6_CI',
#  'Dtnbp1_3_CI',
#  'Dtnbp1_4_CI',
#  'Dtx1_3_CI',
#  'Dtx1_4_CI',
#  'Dus3l_2_CI',
#  'Dus3l_3_CI',
#  'Dus3l_7_CI',
#  'Dus3l_8_CI',
#  'Dus3l_5_CI',
#  'Dusp11_3_CI',
#  'Dusp11_4_CI',
#  'Dut_3_CI',
#  'Dut_1_CI',
#  'Dym_13_CI',
#  'Dym_14_CI',
#  'Dym_15_CI',
#  'Dym_5_CI',
#  'Dym_6_CI',
#  'Dym_16_CI',
#  'Dync1i2_9_CI',
#  'Dync1i2_10_CI',
#  'Dync1li1_3_CI',
#  'Dync1li1_4_CI',
#  'Dync1li1_1_CI',
#  'Dync1li1_9_CI',
#  'Dync1li1_10_CI',
#  'Dync1li2_11_CI',
#  'Dync1li2_12_CI',
#  'Dync1li2_3_CI',
#  'Dync1li2_4_CI',
#  'Dynlt1a_4_CI',
#  'Dzank1_12_CI',
#  'Dzank1_10_CI',
#  'Dzank1_11_CI',
#  'Dzank1_2_CI',
#  'Dzank1_3_CI',
#  'Ech1_2_CI',
#  'Ech1_3_CI',
#  'Echs1_6_CI',
#  'Echs1_7_CI',
#  'Echs1_4_CI',
#  'Edf1_4_CI',
#  'Eef1akmt1_4_CI',
#  'Eef1akmt1_2_CI',
#  'Eef1e1_2_CI',
#  'Eef1g_5_CI',
#  'Eef2_5_CI',
#  'Eef2_6_CI',
#  'Eef2_12_CI',
#  'Eef2_13_CI',
#  'Efr3b_13_CI',
#  'Efr3b_14_CI',
#  'Efr3b_7_CI',
#  'Efr3b_8_CI',
#  'Efr3b_19_CI',
#  'Efr3b_20_CI',
#  'Efr3b_9_CI',
#  'Egln2_2_CI',
#  'Egln2_3_CI',
#  'Ehd1_3_CI',
#  'Ehmt2_2_CI',
#  'Eif1a_2_CI',
#  'Eif1ax_5_CI',
#  'Eif1ax_6_CI',
#  ...]
